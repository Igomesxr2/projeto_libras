# %%
# %pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.22  Python-3.11.0 torch-2.3.0+cpu CPU (Intel Celeron 6305 1.80GHz)
# Setup complete  (2 CPUs, 3.7 GB RAM, 74.3/222.9 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image
